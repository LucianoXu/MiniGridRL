# %% [markdown]
# # MiniGridRL Cookbook

# %% [markdown]
# ## Inspect an environment
#
# An `env` config builds and returns a gym environment.

# %%
from minigridrl import run
env = run("configs/envs/empty5x5.yaml")
env.observation_space

# %% [markdown]
# ## Run a single RL Training

# %%
from minigridrl import run

envs = run("configs/experiments/reinforce_mlp_empty5x5.yaml")
